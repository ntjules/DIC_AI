# %% [markdown]
# <h4> [Problem] The day when Kuri Manju covers the solar system </h4>

# %%
import  matplotlib.pyplot  as plt
# %matplotlib inline 
solarsystem =  149000000000
def reach(targetlength):
    length,every_5_min = 5 ,[5]
    while length < targetlength:
        length += length
        every_5_min.append(length)
        
    return (len(alldays)-1)*5, every_5_min
Minutes,alldays = reach(solarsystem)
print(alldays,len(alldays)-1)  

print(int(Minutes/60), "hours and ",Minutes%60, "Minutes to complete solar system")

plt.title( "Graph " )
plt.xlabel( " rounds every 5 minutes " )
plt.ylabel( " length " )
plt.plot (alldays, color = 'purple', label='gained length')
plt.legend(loc='best')
plt.show()
# Out:
# [5, 10, 20, 40, 80, 160, 320, 640, 1280, 2560, 5120, 10240, 20480, 40960, 81920, 163840, 327680, 655360, 1310720, 2621440, 5242880, 10485760, 20971520, 41943040, 83886080, 167772160, 335544320, 671088640, 1342177280, 2684354560, 5368709120, 10737418240, 21474836480, 42949672960, 85899345920, 171798691840] 35
# 2 hours and  55 Minutes to complete solar system
