# %% [markdown]
# <h4> [Problem 1] Number of wheat on a 2x2 chess board </h4>

# %%
import numpy as np
n_squares = 2*2
small_board_list = np.array([1])
for _ in range(n_squares - 1):
    small_board_list =np.append(small_board_list, 2*small_board_list[-1])
print ( " Arrange wheat on a 2x2 board (list): {} " .format (small_board_list))
# Out:
#  Arrange wheat on a 2x2 board (list): [1 2 4 8]

# %% [markdown]
# <h4> [Problem 2] Expansion to n × m mass </h4>

# %%
import numpy as np
def arraylist(width, height):
    n_squares = width * height
    small_board_list = np.array([1])
    for _ in range(n_squares - 1):
        small_board_list =np.append(small_board_list, 2*small_board_list[-1])
    return small_board_list.astype (np.uint64)
print ( " Arrange wheat on a nxm board (list): {} " .format (arraylist(8, 8)))
# Out:
#  Arrange wheat on a nxm board (list): [                  1                   2                   4
#                    8                  16                  32
#                   64                 128                 256
#                  512                1024                2048
#                 4096                8192               16384
#                32768               65536              131072
#               262144              524288             1048576
#              2097152             4194304             8388608
#             16777216            33554432            67108864
#            134217728           268435456           536870912
#           1073741824          2147483648          4294967296
#           8589934592         17179869184         34359738368
#          68719476736        137438953472        274877906944
#         549755813888       1099511627776       2199023255552
#        4398046511104       8796093022208      17592186044416
# ...

# %% [markdown]
# <h4> [Problem 3] Total number of wheat</h4>

# %%
import  matplotlib.pyplot  as plt
import numpy as np

def arraylist(width, height):
    n_squares = width * height
    small_board_list = np.array([1])
    for _ in range(n_squares - 1):
        small_board_list =np.append(small_board_list, 2*small_board_list[-1])
    return small_board_list.astype (np.uint64)
# print(arraylist(2,2))
mean = arraylist(8,8).mean()
print("average: ", mean)
# %matplotlib inline
plt.xlabel("column")
plt.ylabel("number")
plt.title("number in each column")
plt.bar(np.arange(1,(8**2)+1), arraylist(8,8))
# plt.axvline(arraylist(8,8).mean(), color='blue', linewidth=2, linestyle='--')
plt.show()
# Out:
# average:  2.8823037615171174e+17

# %% [markdown]
# <h4> [Problem 4] Heat map of the number of wheat </h4>

# %%
import  matplotlib.pyplot  as plt
import numpy as np

plt.xlabel("column")
plt.ylabel("row")
plt.title("heatmap")
plt.pcolor(arraylist(8,8).reshape(8, 8))
plt.show()

# %% [markdown]
# <h4> [Problem 5] How many times the second half is the first half </h4>

# %%
n_squares = 8*8
indices_of_squares = np.arange(n_squares)
small_board_ndarray = 2**indices_of_squares

def split_list(list):
    half = len(list)//2
    return list[:half].astype (np.uint64), list[half:].astype (np.uint64)
first_half,second_half = split_list(small_board_ndarray)
print("number of times is ：{}".format(sum(second_half) / sum(first_half)))
# Out:
# number of times is ：4294967296.0

# %% [markdown]
# <h4> [Problem 6] Expansion to n × m mass by other calculation methods </h4>

# %%
import numpy as np
def arraylist_b(width, height):
    n_squares = width * height
    indices_of_squares = np.arange(n_squares)
    small_board_list = 2**indices_of_squares
    
    return small_board_list.astype(np.uint64)
print ( " Arrange wheat on a nxm board (list): {} " .format (arraylist_b(8, 8)))
# Out:
#  Arrange wheat on a nxm board (list): [                  1                   2                   4
#                    8                  16                  32
#                   64                 128                 256
#                  512                1024                2048
#                 4096                8192               16384
#                32768               65536              131072
#               262144              524288             1048576
#              2097152             4194304             8388608
#             16777216            33554432            67108864
#            134217728           268435456           536870912
#           1073741824          2147483648          4294967296
#           8589934592         17179869184         34359738368
#          68719476736        137438953472        274877906944
#         549755813888       1099511627776       2199023255552
#        4398046511104       8796093022208      17592186044416
# ...

# %% [markdown]
# <h4> [Problem 7] Comparison of calculation time </h4>

# %% [markdown]
# <h5> np.append () </h5>

# %%
# %% timeit
# arraylist_b(8, 8)
# Out:
# UsageError: Cell magic `%%` not found.

# %% [markdown]
# <h5> broadcast <h5>
